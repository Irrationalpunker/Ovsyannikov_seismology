# %%
from src.Calculations import Calculation
from geopy.location import Point
from src.Station import Station
from src.Event import Event
from src.geopackager import Interpreter

# %%
I1 = Interpreter()
Stations = I1.s_gpx(r"C:\Users\Irrat\Desktop\2024-07.BBB-BSP.gpx")
picks = I1.p_json(r"C:\Users\Irrat\Downloads\from_Ivan\3_picks\picks_20250816_145032\20240823_191938_247574.json")
C1 = Calculation(vp=8.1,vs=7.3)
print(C1.Inverse_task(stations=Stations, picks=picks))
# Out:
#     station   name        lat         lon    alt        P_time        S_time
# 0         0  BBB01  52.887977  157.738186  342.0  1.724441e+09  1.724441e+09
# 1         0  BSP18  52.864159  157.833418  421.0  1.724441e+09  1.724441e+09
# 2         0  BSP16  52.863355  157.828386  402.0  1.724441e+09  1.724441e+09
# 3         0  BBB05  52.865861  157.851695  503.0  1.724441e+09  1.724441e+09
# 4         0  BSP24  52.861843  157.850218  420.0  1.724441e+09  1.724441e+09
# 5         0  BSP28  52.865708  157.871656  466.0  1.724441e+09  1.724441e+09
# 6         0  BSP11  52.860364  157.798994  388.0  1.724441e+09  1.724441e+09
# 7         0  BSP29  52.865457  157.878178  461.0  1.724441e+09  1.724441e+09
# 8         0  BSP20  52.863950  157.840490  415.0  1.724441e+09  1.724441e+09
# 9         0  BBB03  52.865428  157.825966  412.0  1.724441e+09  1.724441e+09
# 10        0  BSP13  52.861348  157.812514  383.0  1.724441e+09  1.724441e+09
# ...
